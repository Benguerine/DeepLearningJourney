# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/Dive into deep learning with tensorflow"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Add your GitHub repo as a remote
# Replace USERNAME with your GitHub username
# !git remote add origin https://github.com/Benguerine/DeepLearningJourney

# Step 4: Add, commit, and push
# !git add .
# !git commit -m "Initial commit from Colab"
# !git branch -M main

# Replace TOKEN and USERNAME
# !git push https://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@github.com/Benguerine/DeepLearningJourney.git main

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/Dive into deep learning with tensorflow"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin || true  # ignore error if origin doesn't exist
repo_url = f"https://{token}@github.com/Benguerine/DeepLearningJourney.git"
# !git remote add origin {repo_url}

# !git add .
# !git commit -m "Initial commit from Colab"

# !git pull origin main --rebase
# !git push origin main



# Step 3: Add your GitHub repo as a remote
# Replace USERNAME with your GitHub username
# !git remote add origin https://github.com/Benguerine/DeepLearningJourney.git

# Step 4: Add, commit, and push
# !git add .
# !git commit -m "Initial commit from Colab"
# !git branch -M main


# !git remote remove origin
repo_url = f"https://{token}@github.com/Benguerine/DeepLearningJourney.git"
# !git remote add origin {repo_url}
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Dive into deep learning with tensorflow/.git/
# error: remote origin already exists.
# [main 3d869a7] Initial commit from Colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enter your GitHub token: ··········
# To https://github.com/Benguerine/DeepLearningJourney.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Benguerine/DeepLearningJourney.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

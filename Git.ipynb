# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Step 1: Set paths
folder_path = "/content/drive/MyDrive/Dive into deep learning with tensorflow"  # change if needed
os.chdir(folder_path)

# Step 2: Git config
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Add your GitHub repo as a remote
# Replace USERNAME with your GitHub username
# !git remote add origin https://github.com/Benguerine/DeepLearningJourney.git

# Step 4: Add, commit, and push
# !git add .
# !git commit -m "Initial commit from Colab"
# !git branch -M main

from getpass import getpass

token = getpass('Enter your GitHub token: ')

# !git remote remove origin
repo_url = f"https://{token}@github.com/Benguerine/DeepLearningJourney.git"
# !git remote add origin {repo_url}
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Dive into deep learning with tensorflow/.git/
# [master (root-commit) 1bde704] Initial commit from Colab
#  3 files changed, 3 insertions(+)
#  create mode 100644 Git.ipynb
#  create mode 100644 Neural network regression with TensorFlow/Neural_Network_regression_problem.ipynb
#  create mode 100644 the fundamentals of tensorflow/Hands-on-tensorflow.ipynb
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/Benguerine/DeepLearningJourney.git/': The requested URL returned error: 403
